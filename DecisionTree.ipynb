# %%
# This Model Uses a Decision Tree Classifier to predict whether or not customers will pay off their loans and whether or not to accept loan requests

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree

# %%
data = pd.read_csv("data/Decision_Tree_Dataset.csv", sep=",", header=0)
data.head()
# Out:
#      1      2    3     4    sum Unnamed: 5
# 0  201  10018  250  3046  13515        yes
# 1  205  10016  395  3044  13660        yes
# 2  257  10129  109  3251  13746        yes
# 3  246  10064  324  3137  13771        yes
# 4  117  10115  496  3094  13822        yes

# %%
print("Dataset length:", len(data))
print("Dataset shape:", data.shape)
# Out:
# Dataset length: 1000
# Dataset shape: (1000, 6)

# %%
data.drop(columns=['sum'], inplace=True)
data
# Out:
#        1      2    3     4 Unnamed: 5
# 0    201  10018  250  3046        yes
# 1    205  10016  395  3044        yes
# 2    257  10129  109  3251        yes
# 3    246  10064  324  3137        yes
# 4    117  10115  496  3094        yes
# ..   ...    ...  ...   ...        ...
# 995  413  14914  523  4683         No
# 996  359  14423  927  4838         No
# 997  316  14872  613  4760         No
# 998  305  14926  897  4572         No
# 999  168  14798  834  4937         No
#
# [1000 rows x 5 columns]

# %%
data.rename(columns={'1': 'Initial Payment', '2': 'Last Payment', '3':'Credit Score', '4':'House Number', 'Unnamed: 5':'Result'}, inplace=True)

# %%
data
# Out:
#      Initial Payment  Last Payment  Credit Score  House Number Result
# 0                201         10018           250          3046    yes
# 1                205         10016           395          3044    yes
# 2                257         10129           109          3251    yes
# 3                246         10064           324          3137    yes
# 4                117         10115           496          3094    yes
# ..               ...           ...           ...           ...    ...
# 995              413         14914           523          4683     No
# 996              359         14423           927          4838     No
# 997              316         14872           613          4760     No
# 998              305         14926           897          4572     No
# 999              168         14798           834          4937     No
#
# [1000 rows x 5 columns]

# %%
X = data.values[:, 0:4]
y= data.values[:, 4]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2)

# %%
model = DecisionTreeClassifier(criterion='entropy', random_state=2, max_depth=3, min_samples_leaf=5)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=5,
#                        random_state=2)

# %%
y_prediction = model.predict(X_test)
y_prediction
# Out:
# array(['yes', 'No', 'No', 'yes', 'No', 'No', 'No', 'yes', 'No', 'yes',
#        'yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'No', 'yes', 'No', 'yes', 'yes', 'yes', 'No',
#        'No', 'yes', 'yes', 'No', 'yes', 'yes', 'yes', 'No', 'No', 'No',
#        'No', 'No', 'No', 'yes', 'No', 'yes', 'yes', 'No', 'No', 'No',
#        'yes', 'No', 'No', 'yes', 'No', 'No', 'No', 'yes', 'yes', 'No',
#        'yes', 'No', 'yes', 'No', 'yes', 'yes', 'No', 'No', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'No', 'yes', 'yes', 'No', 'No', 'yes', 'No',
#        'No', 'yes', 'No', 'yes', 'No', 'yes', 'No', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'No', 'No', 'yes', 'yes', 'No', 'No', 'No', 'No',
#        'No', 'yes', 'No', 'yes', 'No', 'No', 'yes', 'yes', 'yes', 'No',
#        'No', 'No', 'yes', 'No', 'No', 'yes', 'No', 'No', 'No', 'No',
#        'yes', 'No', 'No', 'yes', 'yes', 'yes', 'No', 'yes', 'yes', 'No',
# ...

# %%
accuracy = accuracy_score(y_test, y_prediction)
print("Total Accuracy:", (accuracy*100))
# Out:
# Total Accuracy: 93.33333333333333
